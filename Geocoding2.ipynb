# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import time
import openpyxl

# %%
INPUT_FILE = "FinalDataset.xlsx"
OUTPUT_FILE = "FinalDataset_Geocoded.csv"

# %%
geolocator = Nominatim(user_agent="real_estate_analysis_app") 

# --- Geocoding Function ---
def geocode_place(place):
    """
    Attempts to geocode a single place name.
    Includes a 1-second delay to respect Nominatim's rate limits.
    """
    # Clean the input string by stripping leading/trailing whitespace
    place = str(place).strip()
    
    # Introduce a delay to avoid hitting rate limits
    time.sleep(1) 
    
    try:
        # Use the geocoder to find the location
        location = geolocator.geocode(place, timeout=10)
        
        if location:
            print(f"Successfully geocoded: {place} -> ({location.latitude}, {location.longitude})")
            return (location.latitude, location.longitude)
        else:
            print(f"Could not find coordinates for: {place}")
            return (None, None)
            
    except GeocoderTimedOut:
        print(f"Geocoding timed out for: {place}. Retrying after 5 seconds...")
        time.sleep(5)
        # Attempt retry (optional, but robust)
        try:
            location = geolocator.geocode(place, timeout=20)
            if location:
                return (location.latitude, location.longitude)
            else:
                return (None, None)
        except Exception:
            return (None, None)
            
    except GeocoderServiceError as e:
        print(f"Service error for {place}: {e}")
        return (None, None)
    except Exception as e:
        print(f"An unexpected error occurred for {place}: {e}")
        return (None, None)

# %%
import os
os.chdir('/Users/nidamaryam/Desktop/Projects/PropertyTax')
os.getcwd()
# Out:
# '/Users/nidamaryam/Desktop/Projects/PropertyTax'

# %%
# --- Main Logic ---
def run_geocoding():
    """Loads data, geocodes places, and saves the new DataFrame."""
    try:
        # 1. Load the dataset
        df = pd.read_excel('FinalDataset.xlsx')
        print(f"Original data loaded successfully. Shape: {df.shape}")
        
        # 2. Clean 'Place' column and identify unique locations
        df['Place_Clean'] = df['Place'].astype(str).str.strip()
        unique_places = df['Place_Clean'].unique()
        print(f"Found {len(unique_places)} unique places to geocode.")
        
        # 3. Create a dictionary to store geocoded results (to avoid redundant API calls)
        geocoded_cache = {}
        
        # 4. Geocode each unique place
        for place in unique_places:
            lat, lon = geocode_place(place)
            geocoded_cache[place] = {'Latitude': lat, 'Longitude': lon}
        
        # 5. Convert cache to a DataFrame for merging
        geo_df = pd.DataFrame.from_dict(geocoded_cache, orient='index').reset_index()
        geo_df.columns = ['Place_Clean', 'Latitude', 'Longitude']
        
        # 6. Merge coordinates back into the original DataFrame
        final_df = pd.merge(df, geo_df, on='Place_Clean', how='left')
        
        # 7. Drop the temporary clean column and reorder columns for clarity
        final_df = final_df.drop(columns=['Place_Clean'])
        
        # 8. Save the final geocoded dataset
        final_df.to_csv(OUTPUT_FILE, index=False)
        print("\n" + "="*50)
        print(f"Geocoding complete! The new file is saved as '{OUTPUT_FILE}'.")
        print("Final DataFrame head with coordinates:")
        print(final_df[['Place', 'Latitude', 'Longitude']].head())
        print("="*50)

    except FileNotFoundError:
        print(f"Error: Input file '{INPUT_FILE}' not found. Please ensure the file is in the correct directory.")
    except Exception as e:
        print(f"An error occurred during the main process: {e}")

# %%
if __name__ == "__main__":
    run_geocoding()
# Out:
# Original data loaded successfully. Shape: (2734, 4)
# Found 316 unique places to geocode.
# Successfully geocoded: Devanahalli, Bangalore -> (13.2483502, 77.7134377)
# Successfully geocoded: Vidyaranyapura, Bangalore -> (13.0766407, 77.5577315)
# Successfully geocoded: Sarjapur, Bangalore -> (12.9116225, 77.6388622)
# Successfully geocoded: Whitefield, Bangalore -> (12.9963995, 77.7614229)
# Successfully geocoded: Rajarajeshwari Nagar, Bangalore -> (12.9274413, 77.5155224)
# Successfully geocoded: Yelahanka, Bangalore -> (13.1006982, 77.5963454)
# Successfully geocoded: Kanakapura Road, Bangalore -> (12.8848574, 77.5526906)
# Successfully geocoded: Sarjapur Road, Bangalore -> (12.9243414, 77.6448784)
# Successfully geocoded: Marathahalli, Bangalore -> (12.9552572, 77.6984163)
# Successfully geocoded: Soukya Road, Whitefield, Bangalore -> (12.9943352, 77.7963018)
# Successfully geocoded: Varthur, Bangalore -> (12.9406508, 77.746988)
# Successfully geocoded: Hoskote, Bangalore -> (13.0318443, 77.7618779)
# Successfully geocoded: Kanakapura, Kanakapura Road -> (12.5564945, 77.424926)
# Successfully geocoded: Electronic City, Bangalore -> (12.8487599, 77.648253)
# Successfully geocoded: Begur, Bangalore -> (12.8633887, 77.6130112)
# Successfully geocoded: Chandapura Anekal Road, Bangalore -> (12.7972786, 77.7063395)
# Successfully geocoded: Electronics City Phase 1, Bangalore -> (12.8401734, 77.6595099)
# Could not find coordinates for: Nisarga Layout, Hoskote
# Successfully geocoded: Hebbal, Bangalore -> (13.0382184, 77.5919)
# Successfully geocoded: KR Puram, Bangalore -> (13.007516, 77.695935)
# Could not find coordinates for: Gunjur, Near Varthur, Bangalore
# Could not find coordinates for: Hebbal Kempapura, Near Hebbal, Bangalore
# Could not find coordinates for: Talaghattapura, Kanakapura Road
# Successfully geocoded: Hennur Road, Bangalore -> (13.0351224, 77.631944)
# Successfully geocoded: Mysore Road, Bangalore -> (12.9467026, 77.5300705)
# Could not find coordinates for: Puttenahalli, 7th Phase JP Nagar
# Successfully geocoded: Electronic City Phase 2, Bangalore -> (12.8471839, 77.6707326)
# Successfully geocoded: Hongasandra, Hosur Road -> (12.9037198, 77.6310564)
# Could not find coordinates for: Samethanahalli, Near Whitefield, Bangalore
# Successfully geocoded: Rajajinagar, Bangalore -> (13.0005232, 77.5496166)
# Successfully geocoded: Koramangala, Bangalore -> (12.9357366, 77.624081)
# Successfully geocoded: Hoodi, Bangalore -> (12.9959233, 77.7192796)
# Could not find coordinates for: Belathur, KR Puram
# Successfully geocoded: Jalahalli, BEL Road, Bangalore -> (13.0516932, 77.552177)
# Successfully geocoded: Rajiv Gandhi Nagar, Sahakara Nagar -> (13.0705182, 77.5869662)
# Successfully geocoded: HSR Layout, Bangalore -> (12.9116225, 77.6388622)
# Successfully geocoded: Thanisandra Main Road, Bangalore North -> (13.043761, 77.6258616)
# Successfully geocoded: Tumkur Road, Bangalore -> (13.0183256, 77.5583364)
# Successfully geocoded: Nagasandra, Bangalore -> (13.0479536, 77.5001422)
# Successfully geocoded: Budigere Cross, Bangalore -> (13.0462134, 77.7504125)
# Successfully geocoded: Gottigere, Bannerghatta Road -> (12.8626123, 77.5906436)
# Successfully geocoded: Banashankari, Bangalore -> (12.9278196, 77.556621)
# Could not find coordinates for: Binny Pete, Magadi Road
# Successfully geocoded: Hosur Road, Bangalore -> (12.9553319, 77.6055123)
# Successfully geocoded: Bannerghatta Road, Bangalore -> (12.8580356, 77.5889558)
# Successfully geocoded: Bannerghatta, Bannerghatta Road -> (12.8947508, 77.5986762)
# Successfully geocoded: 9th Phase JP Nagar, Bangalore -> (12.9102725, 77.5904548)
# Could not find coordinates for: Nandi Hills, Chikkaballapur, Bangalore
# Successfully geocoded: Bommasandra, Bangalore -> (13.0544346, 77.5593269)
# Successfully geocoded: Hosa Road, Bangalore -> (12.8816077, 77.6448181)
# Successfully geocoded: Kengeri, Bangalore -> (12.9176571, 77.4837568)
# Could not find coordinates for: Balagere, Near Panathur, Bangalore
# Successfully geocoded: Nagarbhavi, Bangalore -> (12.9651215, 77.5090098)
# Successfully geocoded: Jigani, Bangalore -> (12.7780787, 77.6357776)
# Successfully geocoded: Doddaballapur, Doddaballapur Road -> (13.2889987, 77.5516969)
# Successfully geocoded: Jakkur, Bangalore -> (13.0784743, 77.6068938)
# Successfully geocoded: IVC Road, Devanahalli -> (13.2310899, 77.6471534)
# Successfully geocoded: Vijayanagar, Bangalore -> (12.9709537, 77.5373851)
# Could not find coordinates for: Nallurhalli, Whitefield
# Successfully geocoded: JP Nagar, Bangalore -> (12.9096941, 77.5866067)
# Successfully geocoded: Panathur, Bangalore -> (12.9351457, 77.7047541)
# Could not find coordinates for: Kogilu, Near Yelahanka, Bangalore
# Successfully geocoded: Chandapura, Bangalore -> (12.8009043, 77.7114908)
# Successfully geocoded: Begur Road, Bangalore -> (12.9051439, 77.6276134)
# Could not find coordinates for: Chokkanahalli, Near Thanisandra, Bangalore
# Successfully geocoded: Bellandur, Bangalore -> (12.9371445, 77.6720227)
# Successfully geocoded: Thanisandra, Bangalore -> (13.054713, 77.6339258)
# Successfully geocoded: Bidadi, Bangalore -> (12.775226, 77.3588237)
# Could not find coordinates for: Chambenahalli, Sarjapur Road
# Successfully geocoded: Banashankari 6th Stage 2nd Block, Bangalore -> (12.8933259, 77.5219378)
# Successfully geocoded: Sadahalli, Devanahalli -> (13.2111088, 77.647022)
# Successfully geocoded: Horamavu, Bangalore -> (13.0273312, 77.6601508)
# Could not find coordinates for: Chikkavaderapura, Near Varthur, Bangalore
# Successfully geocoded: 8th Phase JP Nagar, Bangalore -> (12.9113533, 77.5771148)
# Successfully geocoded: Horamavu Agara, Bangalore -> (13.0367725, 77.6549479)
# Could not find coordinates for: Yadavanahalli, Near Hosur Road, Bangalore
# Could not find coordinates for: Battarahalli, Near KR Puram, Bangalore
# Could not find coordinates for: Attibele, Near Bommasandra, Bangalore
# Successfully geocoded: Kadugodi, Bangalore -> (12.9957428, 77.7579489)
# Successfully geocoded: Bidarahalli, Bangalore -> (13.0619796, 77.7145707)
# Successfully geocoded: Ramanagara, Bangalore -> (12.636283, 77.1263723)
# Could not find coordinates for: Kodathi, Near Sarjapur Road, Bangalore
# Could not find coordinates for: Mallasandra, Near Kanakpura Road, Bangalore
# Successfully geocoded: Pattandur Agrahara, Whitefield -> (12.9876393, 77.7377718)
# Successfully geocoded: Indiranagar, Bangalore -> (12.9732913, 77.6404672)
# Successfully geocoded: Bagalur, Bangalore -> (13.0079918, 77.6184726)
# Successfully geocoded: Old Madras Road, Bangalore -> (13.0082277, 77.6941931)
# Could not find coordinates for: Yerthiganahalli, Bangalore
# Could not find coordinates for: Thondebavi, Bangalore
# Could not find coordinates for: Sudhama Nagar, Mission Road, Bangalore
# Successfully geocoded: Kaggadasapura, Bangalore -> (12.9819618, 77.6784643)
# Successfully geocoded: 7th Phase JP Nagar, Bangalore -> (12.9140693, 77.5945396)
# Successfully geocoded: Kaggalipura, Bangalore -> (12.8089587, 77.5097006)
# Successfully geocoded: Kodihalli, Old Airport Road -> (12.9602158, 77.6457171)
# Successfully geocoded: 5th Phase JP Nagar, Bangalore -> (12.9024591, 77.5971894)
# Successfully geocoded: K.Narayanapura, Thanisandra Main Road -> (13.068006, 77.6334983)
# Could not find coordinates for: Yelahanka New Town, Bellari Road
# Could not find coordinates for: Bidaraguppe, Bangalore South
# Successfully geocoded: Rachenahalli, Bangalore -> (13.0588586, 77.6232576)
# Could not find coordinates for: Manyata Tech Park, Thanisandra Main Road
# Could not find coordinates for: Bheemanakuppe, Near Kengeri, Bangalore
# Could not find coordinates for: Kothanur, Near Hennur, Bangalore
# Successfully geocoded: EPIP Zone, Brookefield -> (12.9668213, 77.7168891)
# Could not find coordinates for: Uttarahalli Manavarthekaval, Kanakapura Road
# Successfully geocoded: Uttarahalli, Bangalore -> (12.9055682, 77.5455438)
# Successfully geocoded: BTM Layout, Bangalore -> (12.9140008, 77.6102821)
# Successfully geocoded: Venkatapura, Bangalore -> (12.8839153, 77.47028)
# Could not find coordinates for: Kumbalgodu, Mysore Road, Bangalore
# Successfully geocoded: Chikkajala, Bangalore -> (13.1679234, 77.6372834)
# Could not find coordinates for: Bettenahalli, Near Yelahanka, Bangalore
# Could not find coordinates for: Ambedkar Colony, Bellari Road
# Could not find coordinates for: Hosakerehalli, Near Raja Rajeshwari Nagar, Bangalore
# Could not find coordinates for: Green View Layout, Mysore Road
# Successfully geocoded: Hulimavu, Bangalore -> (12.8773486, 77.6028031)
# Successfully geocoded: Allalasandra, Bangalore -> (13.090997, 77.5868301)
# Could not find coordinates for: Gattahalli, Near Sarjapur Road, Bangalore
# Successfully geocoded: Doddakallasandra, Kanakapura Road -> (12.8857355, 77.5557448)
# Successfully geocoded: Srinivagilu, Koramangala -> (12.9386964, 77.6259936)
# Could not find coordinates for: Lakshminarayana Pura, Old Airport Road
# Successfully geocoded: Sector 4 HSR Layout , Bangalore -> (12.9144684, 77.6418499)
# Could not find coordinates for: Ramagondanahalli, Whitefitefieldi
# Could not find coordinates for: Dodda Nekkundi, Outer Ring Road Easting Road East
# Successfully geocoded: Doddanagamangala, Bangalore -> (12.8668341, 77.6644155)
# Could not find coordinates for: Thanisandra Main Road, Bangalore Northin Road, Bangalore North
# Could not find coordinates for: Mahalakshmi Puram, Bangalorei Puram, Bangalore
# Could not find coordinates for: Rustam Bagh Layout, Old Airport Road
# Successfully geocoded: Dollar Scheme Colony, BTM Layout -> (12.9181537, 77.6195361)
# Could not find coordinates for: Balaji Layout, Kanakapura Road
# Could not find coordinates for: Vittal Nagar, Kumaraswamy Layout, Kanakapura Road
# Successfully geocoded: Malleshpalya, Kaggadasapura -> (12.9807634, 77.6704632)
# Successfully geocoded: Choodasandra, Hosa Road -> (12.8912787, 77.673507)
# Could not find coordinates for: New Thippasandra, Old Madras Road
# Could not find coordinates for: Konappana Agrahara, Electronic Cityity
# Successfully geocoded: 2nd Phase JP Nagar, Bangalore -> (12.9130162, 77.5897372)
# Successfully geocoded: 1st Block HRBR Layout, Kalyan nagar, Bangalore -> (13.0209724, 77.6291786)
# Could not find coordinates for: Kithaganur, Bangalore
# Successfully geocoded: AECS Layout, Brookefield, Bangalore -> (12.9647797, 77.7183067)
# Could not find coordinates for: Subramanyapura, Kanakapura Road
# Successfully geocoded: Kuvempu Nagar, Bangalore North -> (13.0720475, 77.5416602)
# Could not find coordinates for: Narasimha Layout, Yeshwanthpur
# Successfully geocoded: Hosahalli, Bangalore North -> (12.9690686, 77.5427797)
# Could not find coordinates for: Sadanand Nagar, Old Madras Road
# Successfully geocoded: Banashankari Stage 3, Bangalore -> (12.8849238, 77.5154846)
# Could not find coordinates for: Kanakanagar, Kanakapura Road
# Successfully geocoded: Arkavathy Layout, Bangalore -> (13.067129, 77.621897)
# Could not find coordinates for: Muddayanapalya, Annapurneshwari Nagar , Bangalore
# Successfully geocoded: Sondekoppa, Bangalore -> (13.0204419, 77.3825478)
# Could not find coordinates for: Nisarga Nandana Layout, Jiganigan
# Successfully geocoded: Kaval Byrasandra, Bangalore -> (13.0200235, 77.6092887)
# Successfully geocoded: 1st Block BEL Layout, Vidyaranyapura -> (13.0703809, 77.5554238)
# Successfully geocoded: Aradhana Layout, Bannerghatta Road -> (12.9115865, 77.6002227)
# Could not find coordinates for: Banaswadi Main Road, Bangalore Eastin Road, Bangalore East
# Could not find coordinates for: Vijaynagar, Vijayanagarijayanagar
# Could not find coordinates for: Kattigenahalli, Near Yelahanka, Bangalorei, Near Yelahanka, Bangalore
# Could not find coordinates for: Terracon Residency, Bommasandra
# Could not find coordinates for: 13th Street HKP road cross, Bangalore Central
# Could not find coordinates for: MEG Layout, Mahadevapura
# Successfully geocoded: Sector 7 HSR Layout, Bangalore -> (12.908603, 77.6279136)
# Could not find coordinates for: sun city, kengeri satteli sattelite town, Bangalore Westi
# Successfully geocoded: Roopena Agrahara, HSR Layout, Bangalore South -> (12.9111955, 77.6261256)
# Could not find coordinates for: Suryanagar Phase , Bangalore South
# Could not find coordinates for: Sugama Layout, Begur Road
# Could not find coordinates for: Kothannur, JP Nagar
# Could not find coordinates for: Amarjyoti Nagar, Vijayanagarijayanagar
# Could not find coordinates for: RMV 2nd block 2nd Stage, Bellari Road
# Successfully geocoded: Domlur, Bangalore -> (12.9624669, 77.6381958)
# Could not find coordinates for: Hanumagiri Nagar, Outer Ri Nagar, Outer Ring Road Southi
# Could not find coordinates for: Yelachanayakanapura, Bangalore
# Could not find coordinates for: Ambalipura, Harlur
# Could not find coordinates for: Vidyamanya Nagar, Bangalore
# Could not find coordinates for: Amani Byrathi Byrathikhane, Bangalorei
# Could not find coordinates for: Bidadi, Bangalorei, Bangalore
# Successfully geocoded: Mathikere, Bangalore -> (13.0333587, 77.5581786)
# Successfully geocoded: 1st Stage Indira Nagar, Bangalore -> (12.9779232, 77.6405045)
# Could not find coordinates for: Kannur, Thanisandra Main Roadin Road
# Successfully geocoded: Lakshmipura, Bangalore -> (13.0875408, 77.5314154)
# Could not find coordinates for: Kotiganahalliganahalli, Anekali
# Could not find coordinates for: Kallumantapa, Horamavu
# Successfully geocoded: Tharabanahalli, Bangalore -> (13.1887258, 77.6232812)
# Could not find coordinates for: Arasanakunte, Nelamangala
# Could not find coordinates for: Gamma I Gr Noida, Bangalore North
# Could not find coordinates for: Kengeri Upanagara, Ramasandra, Bangalore
# Successfully geocoded: Dodderi, Bangalore -> (12.8680252, 77.3809612)
# Could not find coordinates for: Talacauvery Layout, Basavanagara, Bangalore
# Could not find coordinates for: Sri Chaitanya PU College, Bangalore Eastitanya PU College, Bangalore East
# Could not find coordinates for: Nagarbhavi 1st Stage, Bangalore
# Could not find coordinates for: Vinayaka Layout,Vinayaka Extensinayaka Extension, Nayandana halli, Bangalore
# Successfully geocoded: HRBR Layout, Kalyan nagar, Bangalore -> (13.0250556, 77.6347105)
# Could not find coordinates for: Dodsworth Layout, Whitefieldield
# Successfully geocoded: Harlur, Bangalore -> (12.9058923, 77.675465)
# Successfully geocoded: Chikkaballapur, Bangalore -> (13.0993764, 77.388729)
# Could not find coordinates for: 2nd Block Sir M Vishweshwaraishweshwaraiah Layout, Ramasandra, Bangalorei
# Successfully geocoded: Gorinabele, Bangalore -> (13.0422939, 77.3645637)
# Successfully geocoded: Abbaiah Reddy Layout , Kaggadasapura -> (12.9838304, 77.6793971)
# Successfully geocoded: Kasavanhalli, Bangalore -> (12.9047595, 77.6759172)
#
# ==================================================
# Geocoding complete! The new file is saved as 'FinalDataset_Geocoded.csv'.
# Final DataFrame head with coordinates:
#                         Place   Latitude  Longitude
# 0      Devanahalli, Bangalore  13.248350  77.713438
# 1   Vidyaranyapura, Bangalore  13.076641  77.557732
# 2   Vidyaranyapura, Bangalore  13.076641  77.557732
# 3         Sarjapur, Bangalore  12.911623  77.638862
# 4         Sarjapur, Bangalore  12.911623  77.638862
# ==================================================
